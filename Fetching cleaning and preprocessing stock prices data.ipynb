# %%
import pandas as pd
import yfinance as yf
import os
from datetime import datetime, timedelta
import logging
import time

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def fetch_tickers_from_csv(file_name):
    """Fetch tickers from a CSV file located in the same directory as the script."""
    try:
        script_dir = os.getcwd()  # Get the current working directory
        file_path = os.path.join(script_dir, file_name)
        df = pd.read_csv(file_path)
        tickers = df['Ticker'].dropna().tolist()
        logging.info(f"Successfully fetched {len(tickers)} tickers from {file_name}.")
        return tickers
    except Exception as e:
        logging.error(f"Error fetching tickers from {file_name}: {e}")
        return []

def fetch_and_collect_data(ticker, start_date, end_date, retries=5):
    """Fetch stock data for a given ticker and return it as a DataFrame."""
    attempt = 0
    while attempt < retries:
        try:
            # Fetch historical data for the ticker
            data = yf.download(ticker, start=start_date.strftime('%Y-%m-%d'), end=end_date.strftime('%Y-%m-%d'), progress=False)
            if not data.empty:
                data['Ticker'] = ticker  # Add a column for the ticker symbol
                data.reset_index(inplace=True)  # Ensure 'Date' column is present
                logging.info(f"Successfully fetched data for {ticker}")
                return data
            else:
                logging.warning(f"No data available for {ticker}")
                return pd.DataFrame()  # Return empty DataFrame if no data
        except Exception as e:
            logging.error(f"Error fetching data for {ticker} on attempt {attempt + 1}: {e}")
            attempt += 1
            time.sleep(5)  # Wait a bit before retrying
    logging.error(f"Failed to fetch data for {ticker} after {retries} attempts.")
    return pd.DataFrame()  # Return empty DataFrame on failure

def clean_data(df):
    """Clean the stock data by handling missing values and removing duplicates."""
    # Handle missing values
    df.ffill(inplace=True)
    df.bfill(inplace=True)

    # Remove duplicates
    df.drop_duplicates(inplace=True)

    # Ensure correct data types
    if 'Date' in df.columns:
        df['Date'] = pd.to_datetime(df['Date'])

    numerical_cols = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
    for col in numerical_cols:
        if col in df.columns:
            df[col] = df[col].astype(float)
    
    return df

def calculate_indicators(data, threshold, ma_length=50):
    """Calculate technical indicators: Bollinger Bands, VWAP, Squeeze, etc."""
    data['MA50'] = data['Close'].rolling(window=ma_length).mean()
    data['MiddleBB'] = data['Close'].rolling(window=20).mean()
    data['UpperBB'] = data['MiddleBB'] + (data['Close'].rolling(window=20).std() * 2)
    data['LowerBB'] = data['MiddleBB'] - (data['Close'].rolling(window=20).std() * 2)
    data['BB_Width'] = (data['UpperBB'] - data['LowerBB']) / data['MiddleBB']
    data['Squeeze'] = (data['BB_Width'] < threshold).astype(int)
    data['VWAP'] = (data['Close'] * data['Volume']).cumsum() / data['Volume'].cumsum()
    data['Low_Lower_Than_Previous'] = (data['Low'] < data['Low'].shift(1)).astype(int)
    data['Close_Above_VWAP'] = (data['Close'] > data['VWAP']).astype(int)
    data['Volume_Increase'] = (data['Volume'] > data['Volume'].rolling(window=5).mean()).astype(int)
    data['Volume_Spike'] = (data['Volume'] > data['Volume'].rolling(window=20).mean() * 1.5).astype(int)
    data['Divergence'] = ((data['Close'] - data['MA50']) / data['MA50']).abs()
    return data

def detect_spring(data, ma_col, rebound_days, rebound_percentage):
    """Identify potential Spring patterns with enhanced conditions."""
    data['Spring'] = ((data['Low_Lower_Than_Previous'] == 1) &
                      (data['Close_Above_VWAP'] == 1) &
                      (data['Volume_Increase'] == 1) &
                      (data['BB_Width'] <= 0.05) &
                      (data['Low'] < data[ma_col]) &
                      (data['Volume_Spike'] == 1)).astype(int)
    return data

def confirm_spring(data, ma_col, rebound_days, rebound_percentage):
    """Confirm Spring patterns by checking future price movements."""
    squeeze_spring = data[(data['Squeeze'] == 1) & (data['Spring'] == 1)].copy()
    squeeze_spring['Days_Between'] = (squeeze_spring['Date'].diff().dt.days.fillna(0).astype(int))  # Use 'Date' for Days_Between
    
    # Initialize 'Confirmed_Spring' with 0
    squeeze_spring['Confirmed_Spring'] = 0

    # Confirm spring by checking rebound above the moving average within the specified days
    for i in range(len(squeeze_spring)):
        date = squeeze_spring.iloc[i]['Date']
        next_days = data.loc[data['Date'] > date].head(rebound_days)  # Use 'Date' to find next days
        if len(next_days) > 1:
            for j in range(len(next_days)):  # Check each subsequent day
                if next_days.iloc[j]['Close'] > squeeze_spring.iloc[i][ma_col] * rebound_percentage:
                    squeeze_spring.at[squeeze_spring.index[i], 'Confirmed_Spring'] = 1
                    break

    return squeeze_spring[squeeze_spring['Confirmed_Spring'] == 1]

def process_stock_data(ticker, start_date, end_date, threshold, rebound_days=3, rebound_percentage=1.02):
    """Fetch, clean, analyze, and return data for stocks matching the squeeze and spring criteria."""
    data = fetch_and_collect_data(ticker, start_date, end_date)
    if data.empty:
        return None

    # Clean data
    data = clean_data(data)

    # Calculate indicators and detect patterns
    data = calculate_indicators(data, threshold)
    data = detect_spring(data, 'MA50', rebound_days, rebound_percentage)
    confirmed_springs = confirm_spring(data, 'MA50', rebound_days, rebound_percentage)
    
    # Ensure that Ticker is not None
    confirmed_springs['Ticker'] = ticker
    
    return confirmed_springs[['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 
                              'Squeeze', 'Spring', 'Days_Between', 'Confirmed_Spring']]

# Main execution
if __name__ == "__main__":
    # Define time range: Last 10 years to today
    end_date = datetime.now()
    start_date = end_date - timedelta(days=10*365)

    # Define Bollinger Band threshold
    bollinger_threshold = 0.05

    # Fetch tickers from all sources
    russell_tickers = fetch_tickers_from_csv('Russel_3000_ticker_list.csv')
    tsx_tickers = fetch_tickers_from_csv('TSX List.csv')
    tsxv_tickers = fetch_tickers_from_csv('TSXV.csv')
    cse_tickers = fetch_tickers_from_csv('CSE Listings.csv')

    # Combine all tickers into one list
    all_tickers = russell_tickers + tsx_tickers + tsxv_tickers + cse_tickers

    results = []

    # Process each ticker
    for ticker in all_tickers:
        logging.info(f"Processing {ticker}...")
        result = process_stock_data(ticker, start_date, end_date, bollinger_threshold)
        if result is not None and not result.empty:
            results.append(result)

    # Combine and save results
    if results:
        combined_results = pd.concat(results, ignore_index=True)
        combined_results.to_parquet("all_stocks_squeeze_spring_results.parquet")
        logging.info("Successfully saved all results to all_stocks_squeeze_spring_results.parquet")
    else:
        logging.info("No confirmed squeeze followed by spring patterns found.")
# Out:
# 2024-09-01 07:59:55,746 - INFO - Successfully fetched 2634 tickers from Russel_3000_ticker_list.csv.
# 2024-09-01 08:00:00,760 - INFO - Processing ACEL...
# 2024-09-01 08:00:00,937 - INFO - Successfully fetched data for ACEL
# 2024-09-01 08:00:00,964 - INFO - Processing ACGL...
# 2024-09-01 08:00:01,168 - INFO - Successfully fetched data for ACGL
# 2024-09-01 08:00:01,195 - INFO - Processing ACHC...
# 2024-09-01 08:00:01,382 - INFO - Successfully fetched data for ACHC
# 2024-09-01 08:00:01,393 - INFO - Processing ACHR...
# 2024-09-01 08:00:01,554 - INFO - Successfully fetched data for ACHR
# 2024-09-01 08:00:01,564 - INFO - Processing ACI...
# 2024-09-01 08:00:01,708 - INFO - Successfully fetched data for ACI
# 2024-09-01 08:00:01,717 - INFO - Processing ACIW...
# 2024-09-01 08:00:01,834 - INFO - Successfully fetched data for ACIW
# 2024-09-01 08:00:01,847 - INFO - Processing ACLS...
# 2024-09-01 08:00:02,050 - INFO - Successfully fetched data for ACLS
# 2024-09-01 08:00:02,060 - INFO - Processing ACLX...
# 2024-09-01 08:00:02,206 - INFO - Successfully fetched data for ACLX
# 2024-09-01 08:00:02,215 - INFO - Processing ACM...
# 2024-09-01 08:00:02,423 - INFO - Successfully fetched data for ACM
# 2024-09-01 08:00:02,437 - INFO - Processing ACMR...
# 2024-09-01 08:00:02,689 - INFO - Successfully fetched data for ACMR
# 2024-09-01 08:00:02,700 - INFO - Processing ACN...
# 2024-09-01 08:00:02,936 - INFO - Successfully fetched data for ACN
# 2024-09-01 08:00:02,950 - INFO - Processing ACNB...
# 2024-09-01 08:00:03,232 - INFO - Successfully fetched data for ACNB
# 2024-09-01 08:00:03,262 - INFO - Processing ACRE...
# 2024-09-01 08:00:03,575 - INFO - Successfully fetched data for ACRE
# 2024-09-01 08:00:03,600 - INFO - Processing ACT...
# 2024-09-01 08:00:03,745 - INFO - Successfully fetched data for ACT
# 2024-09-01 08:00:03,757 - INFO - Processing ACTG...
# 2024-09-01 08:00:03,932 - INFO - Successfully fetched data for ACTG
# 2024-09-01 08:00:03,942 - INFO - Processing ACVA...
# 2024-09-01 08:00:04,087 - INFO - Successfully fetched data for ACVA
# 2024-09-01 08:00:04,097 - INFO - Processing ADBE...
# 2024-09-01 08:00:04,365 - INFO - Successfully fetched data for ADBE
# 2024-09-01 08:00:04,378 - INFO - Processing ADC...
# 2024-09-01 08:00:04,552 - INFO - Successfully fetched data for ADC
# 2024-09-01 08:00:04,566 - INFO - Processing ADEA...
# 2024-09-01 08:00:04,939 - INFO - Successfully fetched data for ADEA
# 2024-09-01 08:00:04,950 - INFO - Processing ADI...
# 2024-09-01 08:00:05,096 - INFO - Successfully fetched data for ADI
# 2024-09-01 08:00:05,106 - INFO - Processing ADM...
# 2024-09-01 08:00:05,282 - INFO - Successfully fetched data for ADM
# 2024-09-01 08:00:05,295 - INFO - Processing ADMA...
# 2024-09-01 08:00:05,421 - INFO - Successfully fetched data for ADMA
# 2024-09-01 08:00:05,432 - INFO - Processing ADNT...
# 2024-09-01 08:00:05,640 - INFO - Successfully fetched data for ADNT
# 2024-09-01 08:00:05,653 - INFO - Processing ADP...
# 2024-09-01 08:00:06,025 - INFO - Successfully fetched data for ADP
# 2024-09-01 08:00:06,050 - INFO - Processing ADPT...
# 2024-09-01 08:00:06,149 - INFO - Successfully fetched data for ADPT
# 2024-09-01 08:00:06,159 - INFO - Processing ADSK...
# 2024-09-01 08:00:06,305 - INFO - Successfully fetched data for ADSK
# 2024-09-01 08:00:06,315 - INFO - Processing ADT...
# 2024-09-01 08:00:06,568 - INFO - Successfully fetched data for ADT
# 2024-09-01 08:00:06,577 - INFO - Processing ADTN...
# 2024-09-01 08:00:06,723 - INFO - Successfully fetched data for ADTN
# 2024-09-01 08:00:06,736 - INFO - Processing ADUS...
# 2024-09-01 08:00:07,004 - INFO - Successfully fetched data for ADUS
# 2024-09-01 08:00:07,017 - INFO - Processing ADV...
# 2024-09-01 08:00:07,116 - INFO - Successfully fetched data for ADV
# 2024-09-01 08:00:07,126 - INFO - Processing AEE...
# 2024-09-01 08:00:07,285 - INFO - Successfully fetched data for AEE
# 2024-09-01 08:00:07,312 - INFO - Processing AEHR...
# 2024-09-01 08:00:07,503 - INFO - Successfully fetched data for AEHR
# 2024-09-01 08:00:07,513 - INFO - Processing AEIS...
# 2024-09-01 08:00:07,657 - INFO - Successfully fetched data for AEIS
# 2024-09-01 08:00:07,667 - INFO - Processing AEO...
# 2024-09-01 08:00:07,933 - INFO - Successfully fetched data for AEO
# 2024-09-01 08:00:07,942 - INFO - Processing AEP...
# 2024-09-01 08:00:08,150 - INFO - Successfully fetched data for AEP
# 2024-09-01 08:00:08,169 - INFO - Processing AES...
# 2024-09-01 08:00:08,490 - INFO - Successfully fetched data for AES
# 2024-09-01 08:00:08,501 - INFO - Processing AESI...
# 2024-09-01 08:00:08,661 - INFO - Successfully fetched data for AESI
# 2024-09-01 08:00:08,669 - INFO - Processing AFCG...
# 2024-09-01 08:00:08,816 - INFO - Successfully fetched data for AFCG
# 2024-09-01 08:00:08,825 - INFO - Processing AFG...
# 2024-09-01 08:00:09,422 - INFO - Successfully fetched data for AFG
# 2024-09-01 08:00:09,445 - INFO - Processing AFL...
# 2024-09-01 08:00:09,714 - INFO - Successfully fetched data for AFL
# 2024-09-01 08:00:09,737 - INFO - Processing AFRM...
# 2024-09-01 08:00:09,917 - INFO - Successfully fetched data for AFRM
# 2024-09-01 08:00:09,928 - INFO - Processing AGCO...
# 2024-09-01 08:00:10,291 - INFO - Successfully fetched data for AGCO
# 2024-09-01 08:00:10,302 - INFO - Processing AGEN...
# 2024-09-01 08:00:10,649 - INFO - Successfully fetched data for AGEN
# 2024-09-01 08:00:10,658 - INFO - Processing AGIO...
# 2024-09-01 08:00:10,882 - INFO - Successfully fetched data for AGIO
# 2024-09-01 08:00:10,893 - INFO - Processing AGL...
# 2024-09-01 08:00:10,991 - INFO - Successfully fetched data for AGL
# 2024-09-01 08:00:11,002 - INFO - Processing AGM...
# 2024-09-01 08:00:11,225 - INFO - Successfully fetched data for AGM
# 2024-09-01 08:00:11,236 - INFO - Processing AGNC...
# 2024-09-01 08:00:11,456 - INFO - Successfully fetched data for AGNC
# 2024-09-01 08:00:11,469 - INFO - Processing AGO...
# 2024-09-01 08:00:11,691 - INFO - Successfully fetched data for AGO
# 2024-09-01 08:00:11,703 - INFO - Processing AGR...
# 2024-09-01 08:00:11,831 - INFO - Successfully fetched data for AGR
# 2024-09-01 08:00:11,848 - INFO - Processing AGS...
# 2024-09-01 08:00:12,159 - INFO - Successfully fetched data for AGS
# 2024-09-01 08:00:12,170 - INFO - Processing AGX...
# 2024-09-01 08:00:12,313 - INFO - Successfully fetched data for AGX
# 2024-09-01 08:00:12,325 - INFO - Processing AGYS...
# 2024-09-01 08:00:12,639 - INFO - Successfully fetched data for AGYS
# 2024-09-01 08:00:12,649 - INFO - Processing AHCO...
# 2024-09-01 08:00:12,860 - INFO - Successfully fetched data for AHCO
# 2024-09-01 08:00:12,875 - INFO - Processing AHH...
# 2024-09-01 08:00:13,014 - INFO - Successfully fetched data for AHH
# 2024-09-01 08:00:13,030 - INFO - Processing AHR...
# 2024-09-01 08:00:13,185 - INFO - Successfully fetched data for AHR
# 2024-09-01 08:00:13,194 - INFO - Processing AI...
# 2024-09-01 08:00:13,436 - INFO - Successfully fetched data for AI
# 2024-09-01 08:00:13,444 - INFO - Processing AIG...
# 2024-09-01 08:00:13,621 - INFO - Successfully fetched data for AIG
# 2024-09-01 08:00:13,634 - INFO - Processing AIN...
# 2024-09-01 08:00:14,043 - INFO - Successfully fetched data for AIN
# 2024-09-01 08:00:14,060 - INFO - Processing AIR...
# 2024-09-01 08:00:14,400 - INFO - Successfully fetched data for AIR
# 2024-09-01 08:00:14,415 - INFO - Processing AIT...
# 2024-09-01 08:00:14,725 - INFO - Successfully fetched data for AIT
# 2024-09-01 08:00:14,737 - INFO - Processing AIV...
# 2024-09-01 08:00:14,943 - INFO - Successfully fetched data for AIV
# 2024-09-01 08:00:14,964 - INFO - Processing AIZ...
# 2024-09-01 08:00:15,130 - INFO - Successfully fetched data for AIZ
# 2024-09-01 08:00:15,146 - INFO - Processing AJG...
# 2024-09-01 08:00:15,365 - INFO - Successfully fetched data for AJG
# 2024-09-01 08:00:15,387 - INFO - Processing AKAM...
# 2024-09-01 08:00:15,567 - INFO - Successfully fetched data for AKAM
# 2024-09-01 08:00:15,584 - INFO - Processing AKR...
# 2024-09-01 08:00:15,785 - INFO - Successfully fetched data for AKR
# 2024-09-01 08:00:15,799 - INFO - Processing AKRO...
# 2024-09-01 08:00:15,908 - INFO - Successfully fetched data for AKRO
# 2024-09-01 08:00:15,917 - INFO - Processing AL...
# 2024-09-01 08:00:16,237 - INFO - Successfully fetched data for AL
# 2024-09-01 08:00:16,251 - INFO - Processing ALAB...
# 2024-09-01 08:00:16,385 - INFO - Successfully fetched data for ALAB
# 2024-09-01 08:00:16,396 - INFO - Processing ALB...
# 2024-09-01 08:00:16,691 - INFO - Successfully fetched data for ALB
# 2024-09-01 08:00:16,703 - INFO - Processing ALDX...
# 2024-09-01 08:00:16,955 - INFO - Successfully fetched data for ALDX
# 2024-09-01 08:00:21,273 - INFO - Processing ALTM...
# 2024-09-01 08:00:21,386 - INFO - Successfully fetched data for ALTM
# 2024-09-01 08:00:21,398 - INFO - Processing ALTR...
# 2024-09-01 08:00:21,511 - INFO - Successfully fetched data for ALTR
# 2024-09-01 08:00:21,521 - INFO - Processing ALX...
# 2024-09-01 08:00:21,667 - INFO - Successfully fetched data for ALX
# 2024-09-01 08:00:21,680 - INFO - Processing ALXO...
# 2024-09-01 08:00:21,775 - INFO - Successfully fetched data for ALXO
# 2024-09-01 08:00:21,784 - INFO - Processing AM...
# 2024-09-01 08:00:21,965 - INFO - Successfully fetched data for AM
# 2024-09-01 08:00:21,975 - INFO - Processing AMAL...
# 2024-09-01 08:00:22,091 - INFO - Successfully fetched data for AMAL
# 2024-09-01 08:00:22,103 - INFO - Processing AMAT...
# 2024-09-01 08:00:22,262 - INFO - Successfully fetched data for AMAT
# 2024-09-01 08:00:22,272 - INFO - Processing AMBA...
# 2024-09-01 08:00:22,416 - INFO - Successfully fetched data for AMBA
# 2024-09-01 08:00:22,426 - INFO - Processing AMBC...
# 2024-09-01 08:00:22,557 - INFO - Successfully fetched data for AMBC
# 2024-09-01 08:00:22,568 - INFO - Processing AMBP...
# 2024-09-01 08:00:22,681 - INFO - Successfully fetched data for AMBP
# 2024-09-01 08:00:22,691 - INFO - Processing AMC...
# 2024-09-01 08:00:22,822 - INFO - Successfully fetched data for AMC
# 2024-09-01 08:00:22,834 - INFO - Processing AMCR...
# 2024-09-01 08:00:22,976 - INFO - Successfully fetched data for AMCR
# 2024-09-01 08:00:22,993 - INFO - Processing AMCX...
# 2024-09-01 08:00:23,101 - INFO - Successfully fetched data for AMCX
# 2024-09-01 08:00:23,111 - INFO - Processing AMD...
# 2024-09-01 08:00:23,227 - INFO - Successfully fetched data for AMD
# 2024-09-01 08:00:23,236 - INFO - Processing AME...
# 2024-09-01 08:00:23,400 - INFO - Successfully fetched data for AME
# 2024-09-01 08:00:23,419 - INFO - Processing AMED...
# 2024-09-01 08:00:23,556 - INFO - Successfully fetched data for AMED
# 2024-09-01 08:00:23,567 - INFO - Processing AMG...
# 2024-09-01 08:00:23,711 - INFO - Successfully fetched data for AMG
# 2024-09-01 08:00:23,722 - INFO - Processing AMGN...
# 2024-09-01 08:00:23,882 - INFO - Successfully fetched data for AMGN
# 2024-09-01 08:00:23,897 - INFO - Processing AMH...
# 2024-09-01 08:00:24,038 - INFO - Successfully fetched data for AMH
# 2024-09-01 08:00:24,058 - INFO - Processing AMK...
# 2024-09-01 08:00:24,180 - INFO - Successfully fetched data for AMK
# 2024-09-01 08:00:24,193 - INFO - Processing AMKR...
# 2024-09-01 08:00:24,335 - INFO - Successfully fetched data for AMKR
# 2024-09-01 08:00:24,345 - INFO - Processing AMN...
# 2024-09-01 08:00:24,474 - INFO - Successfully fetched data for AMN
# 2024-09-01 08:00:24,485 - INFO - Processing AMP...
# 2024-09-01 08:00:24,815 - INFO - Successfully fetched data for AMP
# 2024-09-01 08:00:28,461 - INFO - Processing ANNX...
# 2024-09-01 08:00:28,649 - INFO - Successfully fetched data for ANNX
# 2024-09-01 08:00:28,657 - INFO - Processing ANSS...
# 2024-09-01 08:00:28,790 - INFO - Successfully fetched data for ANSS
# 2024-09-01 08:00:28,809 - INFO - Processing AON...
# 2024-09-01 08:00:29,005 - INFO - Successfully fetched data for AON
# 2024-09-01 08:00:29,026 - INFO - Processing AORT...
# 2024-09-01 08:00:29,223 - INFO - Successfully fetched data for AORT
# 2024-09-01 08:00:29,233 - INFO - Processing AOS...
# 2024-09-01 08:00:29,410 - INFO - Successfully fetched data for AOS
# 2024-09-01 08:00:29,434 - INFO - Processing AOSL...
# 2024-09-01 08:00:29,549 - INFO - Successfully fetched data for AOSL
# 2024-09-01 08:00:29,560 - INFO - Processing APA...
# 2024-09-01 08:00:29,768 - INFO - Successfully fetched data for APA
# 2024-09-01 08:00:29,777 - INFO - Processing APAM...
# 2024-09-01 08:00:29,967 - INFO - Successfully fetched data for APAM
# 2024-09-01 08:00:29,976 - INFO - Processing APD...
# 2024-09-01 08:00:30,185 - INFO - Successfully fetched data for APD
# 2024-09-01 08:00:30,209 - INFO - Processing APG...
# 2024-09-01 08:00:30,309 - INFO - Successfully fetched data for APG
# 2024-09-01 08:00:30,320 - INFO - Processing APGE...
# 2024-09-01 08:00:30,480 - INFO - Successfully fetched data for APGE
# 2024-09-01 08:00:30,488 - INFO - Processing APH...
# 2024-09-01 08:00:30,682 - INFO - Successfully fetched data for APH
# 2024-09-01 08:00:30,701 - INFO - Processing APLD...
# 2024-09-01 08:00:30,837 - INFO - Successfully fetched data for APLD
# 2024-09-01 08:00:30,845 - INFO - Processing APLE...
# 2024-09-01 08:00:31,117 - INFO - Successfully fetched data for APLE
# 2024-09-01 08:00:31,129 - INFO - Processing APLS...
# 2024-09-01 08:00:31,412 - INFO - Successfully fetched data for APLS
# 2024-09-01 08:00:31,422 - INFO - Processing APLT...
# 2024-09-01 08:00:31,537 - INFO - Successfully fetched data for APLT
# 2024-09-01 08:00:31,547 - INFO - Processing APO...
# 2024-09-01 08:00:31,738 - INFO - Successfully fetched data for APO
# 2024-09-01 08:00:31,751 - INFO - Processing APOG...
# 2024-09-01 08:00:31,927 - INFO - Successfully fetched data for APOG
# 2024-09-01 08:00:31,939 - INFO - Processing APP...
# 2024-09-01 08:00:32,098 - INFO - Successfully fetched data for APP
# 2024-09-01 08:00:32,107 - INFO - Processing APPF...
# 2024-09-01 08:00:32,469 - INFO - Successfully fetched data for APPF
# 2024-09-01 08:00:32,481 - INFO - Processing APPN...
# 2024-09-01 08:00:32,608 - INFO - Successfully fetched data for APPN
# 2024-09-01 08:00:32,619 - INFO - Processing APPS...
# 2024-09-01 08:00:32,731 - INFO - Successfully fetched data for APPS
# 2024-09-01 08:00:32,741 - INFO - Processing APTV...
# 2024-09-01 08:00:32,887 - INFO - Successfully fetched data for APTV
# 2024-09-01 08:00:32,899 - INFO - Processing AR...
# 2024-09-01 08:00:42,343 - INFO - Processing ATRO...
# 2024-09-01 08:00:42,552 - INFO - Successfully fetched data for ATRO
# 2024-09-01 08:00:42,562 - INFO - Processing ATSG...
# 2024-09-01 08:00:42,757 - INFO - Successfully fetched data for ATSG
# 2024-09-01 08:00:42,768 - INFO - Processing ATXS...
# 2024-09-01 08:00:42,942 - INFO - Successfully fetched data for ATXS
# 2024-09-01 08:00:42,953 - INFO - Processing AUB...
# 2024-09-01 08:00:43,191 - INFO - Successfully fetched data for AUB
# 2024-09-01 08:00:43,204 - INFO - Processing AUPH...
# 2024-09-01 08:00:43,347 - INFO - Successfully fetched data for AUPH
# 2024-09-01 08:00:43,358 - INFO - Processing AUR...
# 2024-09-01 08:00:43,454 - INFO - Successfully fetched data for AUR
# 2024-09-01 08:00:43,464 - INFO - Processing AURA...
# 2024-09-01 08:00:43,611 - INFO - Successfully fetched data for AURA
# 2024-09-01 08:00:43,621 - INFO - Processing AVA...
# 2024-09-01 08:00:43,814 - INFO - Successfully fetched data for AVA
# 2024-09-01 08:00:43,847 - INFO - Processing AVAV...
# 2024-09-01 08:00:44,062 - INFO - Successfully fetched data for AVAV
# 2024-09-01 08:00:44,074 - INFO - Processing AVB...
# 2024-09-01 08:00:44,344 - INFO - Successfully fetched data for AVB
# 2024-09-01 08:00:44,367 - INFO - Processing AVD...
# 2024-09-01 08:00:44,563 - INFO - Successfully fetched data for AVD
# 2024-09-01 08:00:44,573 - INFO - Processing AVDL...
# 2024-09-01 08:00:44,704 - INFO - Successfully fetched data for AVDL
# 2024-09-01 08:00:44,714 - INFO - Processing AVDX...
# 2024-09-01 08:00:44,874 - INFO - Successfully fetched data for AVDX
# 2024-09-01 08:00:44,883 - INFO - Processing AVGO...
# 2024-09-01 08:00:45,249 - INFO - Successfully fetched data for AVGO
# 2024-09-01 08:00:45,262 - INFO - Processing AVIR...
# 2024-09-01 08:00:45,374 - INFO - Successfully fetched data for AVIR
# 2024-09-01 08:00:45,383 - INFO - Processing AVNS...
# 2024-09-01 08:00:45,512 - INFO - Successfully fetched data for AVNS
# 2024-09-01 08:00:45,524 - INFO - Processing AVNT...
# 2024-09-01 08:00:45,684 - INFO - Successfully fetched data for AVNT
# 2024-09-01 08:00:45,697 - INFO - Processing AVNW...
# 2024-09-01 08:00:45,826 - INFO - Successfully fetched data for AVNW
# 2024-09-01 08:00:45,837 - INFO - Processing AVO...
# 2024-09-01 08:00:46,000 - INFO - Successfully fetched data for AVO
# 2024-09-01 08:00:46,008 - INFO - Processing AVPT...
# 2024-09-01 08:00:46,204 - INFO - Successfully fetched data for AVPT
# 2024-09-01 08:00:46,216 - INFO - Processing AVT...
# 2024-09-01 08:00:46,390 - INFO - Successfully fetched data for AVT
# 2024-09-01 08:00:46,405 - INFO - Processing AVTE...
# 2024-09-01 08:00:46,500 - INFO - Successfully fetched data for AVTE
# 2024-09-01 08:00:46,507 - INFO - Processing AVTR...
# 2024-09-01 08:00:46,672 - INFO - Successfully fetched data for AVTR
# 2024-09-01 08:00:46,682 - INFO - Processing AVXL...
# 2024-09-01 08:00:46,829 - INFO - Successfully fetched data for AVXL
# 2024-09-01 08:00:46,839 - INFO - Processing AVY...
# 2024-09-01 08:00:47,047 - INFO - Successfully fetched data for AVY
# 2024-09-01 08:00:47,063 - INFO - Processing AWI...
# 2024-09-01 08:00:47,236 - INFO - Successfully fetched data for AWI
# 2024-09-01 08:00:47,253 - INFO - Processing AWK...
# 2024-09-01 08:00:47,472 - INFO - Successfully fetched data for AWK
# 2024-09-01 08:00:47,492 - INFO - Processing AWR...
# 2024-09-01 08:00:47,693 - INFO - Successfully fetched data for AWR
# 2024-09-01 08:00:47,709 - INFO - Processing AX...
# 2024-09-01 08:00:47,832 - INFO - Successfully fetched data for AX
# 2024-09-01 08:00:47,841 - INFO - Processing AXGN...
# 2024-09-01 08:00:47,987 - INFO - Successfully fetched data for AXGN
# 2024-09-01 08:00:47,996 - INFO - Processing AXL...
# 2024-09-01 08:00:48,143 - INFO - Successfully fetched data for AXL
# 2024-09-01 08:00:48,154 - INFO - Processing AXNX...
# 2024-09-01 08:00:48,268 - INFO - Successfully fetched data for AXNX
# 2024-09-01 08:00:48,279 - INFO - Processing AXON...
# 2024-09-01 08:00:48,406 - INFO - Successfully fetched data for AXON
# 2024-09-01 08:00:48,417 - INFO - Processing AXP...
# 2024-09-01 08:00:48,593 - INFO - Successfully fetched data for AXP
# 2024-09-01 08:00:48,606 - INFO - Processing AXS...
# 2024-09-01 08:00:48,781 - INFO - Successfully fetched data for AXS
# 2024-09-01 08:00:48,807 - INFO - Processing AXSM...
# 2024-09-01 08:00:48,967 - INFO - Successfully fetched data for AXSM
# 2024-09-01 08:00:48,977 - INFO - Processing AXTA...
# 2024-09-01 08:00:49,093 - INFO - Successfully fetched data for AXTA
# 2024-09-01 08:00:49,109 - INFO - Processing AYI...
# 2024-09-01 08:00:49,265 - INFO - Successfully fetched data for AYI
# 2024-09-01 08:00:49,274 - INFO - Processing AZEK...
# 2024-09-01 08:00:49,392 - INFO - Successfully fetched data for AZEK
# 2024-09-01 08:00:49,400 - INFO - Processing AZO...
# 2024-09-01 08:00:49,532 - INFO - Successfully fetched data for AZO
# 2024-09-01 08:00:49,552 - INFO - Processing AZPN...
# 2024-09-01 08:00:49,701 - INFO - Successfully fetched data for AZPN
# 2024-09-01 08:00:49,715 - INFO - Processing AZTA...
# 2024-09-01 08:00:49,858 - INFO - Successfully fetched data for AZTA
# 2024-09-01 08:00:49,867 - INFO - Processing AZZ...
# 2024-09-01 08:00:50,043 - INFO - Successfully fetched data for AZZ
# 2024-09-01 08:00:50,054 - INFO - Processing B...
# 2024-09-01 08:00:50,230 - INFO - Successfully fetched data for B
# 2024-09-01 08:00:50,245 - INFO - Processing BA...
# 2024-09-01 08:00:50,481 - INFO - Successfully fetched data for BA
# 2024-09-01 08:00:50,493 - INFO - Processing BAC...
# 2024-09-01 08:00:50,682 - INFO - Successfully fetched data for BAC
# 2024-09-01 08:00:50,694 - INFO - Processing BAH...
# 2024-09-01 08:00:55,750 - INFO - Successfully fetched data for BCRX
# 2024-09-01 08:00:55,760 - INFO - Processing BDC...
# 2024-09-01 08:00:56,169 - INFO - Successfully fetched data for BDC
# 2024-09-01 08:00:56,180 - INFO - Processing BDN...
# 2024-09-01 08:00:56,354 - INFO - Successfully fetched data for BDN
# 2024-09-01 08:00:56,371 - INFO - Processing BDX...
# 2024-09-01 08:00:56,651 - INFO - Successfully fetched data for BDX
# 2024-09-01 08:00:56,670 - INFO - Processing BE...
# 2024-09-01 08:00:56,791 - INFO - Successfully fetched data for BE
# 2024-09-01 08:00:56,800 - INFO - Processing BEAM...
# 2024-09-01 08:00:56,915 - INFO - Successfully fetched data for BEAM
# 2024-09-01 08:00:56,925 - INFO - Processing BECN...
# 2024-09-01 08:00:57,088 - INFO - Successfully fetched data for BECN
# 2024-09-01 08:00:57,098 - INFO - Processing BELFB...
# 2024-09-01 08:00:57,366 - INFO - Successfully fetched data for BELFB
# 2024-09-01 08:00:57,377 - INFO - Processing BEN...
# 2024-09-01 08:00:57,552 - INFO - Successfully fetched data for BEN
# 2024-09-01 08:00:57,562 - INFO - Processing BEPC...
# 2024-09-01 08:00:57,677 - INFO - Successfully fetched data for BEPC
# 2024-09-01 08:00:57,687 - INFO - Processing BERY...
# 2024-09-01 08:00:57,832 - INFO - Successfully fetched data for BERY
# 2024-09-01 08:00:57,846 - INFO - Processing BF.A...
# 2024-09-01 08:00:59,340 - ERROR -
# 1 Failed download:
# 2024-09-01 08:00:59,341 - ERROR - ['BF.A']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-09-01 08:00:59,342 - WARNING - No data available for BF.A
# 2024-09-01 08:00:59,343 - INFO - Processing BFAM...
# 2024-09-01 08:00:59,527 - INFO - Successfully fetched data for BFAM
# 2024-09-01 08:00:59,547 - INFO - Processing BF.B...
# 2024-09-01 08:00:59,620 - ERROR -
# 1 Failed download:
# 2024-09-01 08:00:59,620 - ERROR - ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2014-09-04 -> 2024-09-01)')
# 2024-09-01 08:00:59,622 - WARNING - No data available for BF.B
# 2024-09-01 08:00:59,622 - INFO - Processing BFC...
# 2024-09-01 08:00:59,760 - INFO - Successfully fetched data for BFC
# 2024-09-01 08:00:59,793 - INFO - Processing BFH...
# 2024-09-01 08:00:59,947 - INFO - Successfully fetched data for BFH
# 2024-09-01 08:00:59,958 - INFO - Processing BFS...
# 2024-09-01 08:01:00,117 - INFO - Successfully fetched data for BFS
# 2024-09-01 08:01:00,126 - INFO - Processing BFST...
# 2024-09-01 08:01:00,271 - INFO - Successfully fetched data for BFST
# 2024-09-01 08:01:00,285 - INFO - Processing BG...
# 2024-09-01 08:01:00,441 - INFO - Successfully fetched data for BG
# 2024-09-01 08:01:00,455 - INFO - Processing BGC...
# 2024-09-01 08:01:00,676 - INFO - Successfully fetched data for BGC
# 2024-09-01 08:01:00,688 - INFO - Processing BGS...
# 2024-09-01 08:01:00,862 - INFO - Successfully fetched data for BGS
# 2024-09-01 08:01:00,880 - INFO - Processing BHB...
# 2024-09-01 08:01:01,206 - INFO - Successfully fetched data for BHB
